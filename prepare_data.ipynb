# %%
import dataset_tool
tfrecord_dir = 'datasets/lfw/lfw32_tfrecords'
lfw32_dir = 'datasets/lfw/lfw-deepfunneled-32'
import ipdb; ipdb.set_trace() # debugging starts here
dataset_tool.create_lfw32(tfrecord_dir, lfw32_dir, with_attributes=True)
# Out:
# --Return--
# None
# > <ipython-input-2-e24f52261b1e>(4)<module>()
#       3 lfw32_dir = 'datasets/lfw/lfw-deepfunneled-32'
# ----> 4 import ipdb; ipdb.set_trace() # debugging starts here
#       5 dataset_tool.create_lfw32(tfrecord_dir, lfw32_dir, with_attributes=True)
#
# ipdb> tbreak 5
# Breakpoint 1 at <ipython-input-2-e24f52261b1e>:5
# ipdb> n
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2913)run_code()
#    2912                 # Reset our crash handler in place
# -> 2913                 sys.excepthook = old_excepthook
#    2914         except SystemExit as e:
#
# ipdb> c
# Deleted breakpoint 1 at <ipython-input-2-e24f52261b1e>:5
# None
# > <ipython-input-2-e24f52261b1e>(5)<module>()
#       3 lfw32_dir = 'datasets/lfw/lfw-deepfunneled-32'
#       4 import ipdb; ipdb.set_trace() # debugging starts here
# ----> 5 dataset_tool.create_lfw32(tfrecord_dir, lfw32_dir, with_attributes=True)
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(436)create_lfw32()
#     435
# --> 436 def create_lfw32(tfrecord_dir, lfw32_dir, cx=32, cy=32, with_attributes=True):
#     437     if with_attributes:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(437)create_lfw32()
#     436 def create_lfw32(tfrecord_dir, lfw32_dir, cx=32, cy=32, with_attributes=True):
# --> 437     if with_attributes:
#     438         print('Loading LFW32 from "%s"' % lfw32_dir)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(438)create_lfw32()
#     437     if with_attributes:
# --> 438         print('Loading LFW32 from "%s"' % lfw32_dir)
#     439         glob_pattern = os.path.join(lfw32_dir, '*.jpg')
#
# ipdb> n
# Loading LFW32 from "datasets/lfw/lfw-deepfunneled-32"
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(439)create_lfw32()
#     438         print('Loading LFW32 from "%s"' % lfw32_dir)
# --> 439         glob_pattern = os.path.join(lfw32_dir, '*.jpg')
#     440         image_filenames = sorted(glob.glob(glob_pattern))
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(440)create_lfw32()
#     439         glob_pattern = os.path.join(lfw32_dir, '*.jpg')
# --> 440         image_filenames = sorted(glob.glob(glob_pattern))
#     441         expected_images = 13233
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(441)create_lfw32()
#     440         image_filenames = sorted(glob.glob(glob_pattern))
# --> 441         expected_images = 13233
#     442         if len(image_filenames) != expected_images:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(442)create_lfw32()
#     441         expected_images = 13233
# --> 442         if len(image_filenames) != expected_images:
#     443             error('Expected to find %d images' % expected_images)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(445)create_lfw32()
#     444
# --> 445         def get_label(label_string):
#     446             label = label_string.split('\t')[0:2]
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(455)create_lfw32()
#     454
# --> 455         labels_filename = os.path.join(lfw32_dir, 'lfw_attributes.txt')
#     456         labels_file  = open(labels_filename, "r")
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(456)create_lfw32()
#     455         labels_filename = os.path.join(lfw32_dir, 'lfw_attributes.txt')
# --> 456         labels_file  = open(labels_filename, "r")
#     457         labels_string = labels_file.readlines()
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(457)create_lfw32()
#     456         labels_file  = open(labels_filename, "r")
# --> 457         labels_string = labels_file.readlines()
#     458         attributes_headline = labels_string[1].split('\t')[3:]
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(458)create_lfw32()
#     457         labels_string = labels_file.readlines()
# --> 458         attributes_headline = labels_string[1].split('\t')[3:]
#     459         labels_string = sorted(labels_string[2:], key=lambda label_string: get_label(label_string))
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(459)create_lfw32()
#     458         attributes_headline = labels_string[1].split('\t')[3:]
# --> 459         labels_string = sorted(labels_string[2:], key=lambda label_string: get_label(label_string))
#     460
#
# ipdb> attributes_headline
# ['Male', 'Asian', 'White', 'Black', 'Baby', 'Child', 'Youth', 'Middle Aged', 'Senior', 'Black Hair', 'Blond Hair', 'Brown Hair', 'Bald', 'No Eyewear', 'Eyeglasses', 'Sunglasses', 'Mustache', 'Smiling', 'Frowning', 'Chubby', 'Blurry', 'Harsh Lighting', 'Flash', 'Soft Lighting', 'Outdoor', 'Curly Hair', 'Wavy Hair', 'Straight Hair', 'Receding Hairline', 'Bangs', 'Sideburns', 'Fully Visible Forehead', 'Partially Visible Forehead', 'Obstructed Forehead', 'Bushy Eyebrows', 'Arched Eyebrows', 'Narrow Eyes', 'Eyes Open', 'Big Nose', 'Pointy Nose', 'Big Lips', 'Mouth Closed', 'Mouth Slightly Open', 'Mouth Wide Open', 'Teeth Not Visible', 'No Beard', 'Goatee', 'Round Jaw', 'Double Chin', 'Wearing Hat', 'Oval Face', 'Square Face', 'Round Face', 'Color Photo', 'Posed Photo', 'Attractive Man', 'Attractive Woman', 'Indian', 'Gray Hair', 'Bags Under Eyes', 'Heavy Makeup', 'Rosy Cheeks', 'Shiny Skin', 'Pale Skin', "5 o' Clock Shadow", 'Strong Nose-Mouth Lines', 'Wearing Lipstick', 'Flushed Face', 'High Cheekbones', 'Brown Eyes', 'Wearing Earrings', 'Wearing Necktie', 'Wearing Necklace\n']
# ipdb> attributes_headline = attributes_headline[0]
# ipdb> attributes_headline
# 'Male'
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(462)create_lfw32()
#     461         ##Which attributes belong to which image
# --> 462         file_count = 0
#     463         label_id = []
#
# ipdb> labels_string[0]
# 'AJ Cook\t1\t-2.10431357117\t-2.04964414296\t1.59159997371\t-1.04568493968\t-2.23237621545\t-0.911712116356\t0.613642321038\t-0.781886979948\t-0.469518877677\t-2.13402203091\t0.259740167042\t-0.399167907719\t-0.955020907323\t1.39819763866\t-1.67266228528\t-1.91367312834\t-1.56878337998\t1.21737784682\t-1.09140659996\t-1.08421373517\t0.113658071774\t-1.07025086221\t-1.34906799516\t1.4719362585\t-0.193660610157\t-1.17973718697\t0.797966941173\t-0.199745139162\t-0.189665124679\t-1.45967351489\t-0.715645852863\t0.49214530015\t-0.590753813991\t-1.66289061297\t-1.69765966704\t0.595204591575\t0.183200251415\t1.17726248221\t-0.820957487319\t0.878082029834\t0.199701633594\t-2.02253806552\t1.03180200387\t-0.766860889455\t-1.62962724296\t1.93900912605\t-1.62183250712\t0.472360873888\t-0.650781108817\t-1.04412317441\t0.75562716163\t-0.889680288788\t-0.179141374893\t3.9702067791\t0.173076860693\t-0.218302318382\t0.215713652213\t-1.20416138743\t-0.264377125787\t-0.560254364213\t0.339852200084\t-1.06715335283\t-0.643451534157\t0.355319384679\t-2.12437428631\t0.262076706724\t1.00258630557\t-2.47039242106\t0.393497602764\t0.504408518907\t0.256224585196\t-0.676691064125\t0.651946140588\n'
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(463)create_lfw32()
#     462         file_count = 0
# --> 463         label_id = []
#     464         corresponding_image_id = []
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(464)create_lfw32()
#     463         label_id = []
# --> 464         corresponding_image_id = []
#     465         images_length = len(image_filenames)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(465)create_lfw32()
#     464         corresponding_image_id = []
# --> 465         images_length = len(image_filenames)
#     466         found = 1
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(466)create_lfw32()
#     465         images_length = len(image_filenames)
# --> 466         found = 1
#     467         for i in range(len(labels_string)):
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(467)create_lfw32()
#     466         found = 1
# --> 467         for i in range(len(labels_string)):
#     468             file_count = i
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(468)create_lfw32()
#     467         for i in range(len(labels_string)):
# --> 468             file_count = i
#     469             label_filename = get_label(labels_string[i])
#
# ipdb> nn
# *** NameError: name 'nn' is not defined
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(469)create_lfw32()
#     468             file_count = i
# --> 469             label_filename = get_label(labels_string[i])
#     470             while (label_filename != image_filenames[file_count].split('/')[-1]):
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(470)create_lfw32()
#     469             label_filename = get_label(labels_string[i])
# --> 470             while (label_filename != image_filenames[file_count].split('/')[-1]):
#     471                 file_count += 1
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(477)create_lfw32()
#     476                     error('Expected to find %s image' % image_filenames[file_count].split('/')[-1])
# --> 477             if found:
#     478                 label_id.append(i)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(478)create_lfw32()
#     477             if found:
# --> 478                 label_id.append(i)
#     479                 corresponding_image_id.append(file_count) #the index of the attributes along with the index of the image
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(479)create_lfw32()
#     478                 label_id.append(i)
# --> 479                 corresponding_image_id.append(file_count) #the index of the attributes along with the index of the image
#     480             found = 1
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(480)create_lfw32()
#     479                 corresponding_image_id.append(file_count) #the index of the attributes along with the index of the image
# --> 480             found = 1
#     481
#
# ipdb> tbreak 482
# Breakpoint 2 at /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py:482
# ipdb> c
# Deleted breakpoint 2 at /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py:482
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(482)create_lfw32()
#     481
# --> 482         attributes = [[float(attribute.strip('\n')) for attribute in label_string.split('\t')[2:]] for label_string in labels_string]
#     483         attributes = np.asarray(attributes)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(483)create_lfw32()
#     482         attributes = [[float(attribute.strip('\n')) for attribute in label_string.split('\t')[2:]] for label_string in labels_string]
# --> 483         attributes = np.asarray(attributes)
#     484
#
# ipdb> attributes = [[float(attribute.strip('\n')) for attribute in label_string.split('\t')[2:3]] for label_string in labels_string]
# ipdb> attributes[0:10]
# [[-2.10431357117], [0.0613136924102], [1.56834639173], [0.169850615079], [0.997748978625], [1.12271853446], [1.07821423781], [0.850491041965], [0.944548239019], [1.5946711165]]
# ipdb> corresponding_image_id[0]
# 0
# ipdb> label_id[0]
# 0
# ipdb> labels_string[0]
# 'AJ Cook\t1\t-2.10431357117\t-2.04964414296\t1.59159997371\t-1.04568493968\t-2.23237621545\t-0.911712116356\t0.613642321038\t-0.781886979948\t-0.469518877677\t-2.13402203091\t0.259740167042\t-0.399167907719\t-0.955020907323\t1.39819763866\t-1.67266228528\t-1.91367312834\t-1.56878337998\t1.21737784682\t-1.09140659996\t-1.08421373517\t0.113658071774\t-1.07025086221\t-1.34906799516\t1.4719362585\t-0.193660610157\t-1.17973718697\t0.797966941173\t-0.199745139162\t-0.189665124679\t-1.45967351489\t-0.715645852863\t0.49214530015\t-0.590753813991\t-1.66289061297\t-1.69765966704\t0.595204591575\t0.183200251415\t1.17726248221\t-0.820957487319\t0.878082029834\t0.199701633594\t-2.02253806552\t1.03180200387\t-0.766860889455\t-1.62962724296\t1.93900912605\t-1.62183250712\t0.472360873888\t-0.650781108817\t-1.04412317441\t0.75562716163\t-0.889680288788\t-0.179141374893\t3.9702067791\t0.173076860693\t-0.218302318382\t0.215713652213\t-1.20416138743\t-0.264377125787\t-0.560254364213\t0.339852200084\t-1.06715335283\t-0.643451534157\t0.355319384679\t-2.12437428631\t0.262076706724\t1.00258630557\t-2.47039242106\t0.393497602764\t0.504408518907\t0.256224585196\t-0.676691064125\t0.651946140588\n'
# ipdb> labels_string[1]
# 'AJ Lamas\t1\t0.0613136924102\t-1.20384321813\t0.190530027481\t-1.44969253971\t-2.19383696181\t-0.707221051522\t0.424077422335\t-0.337895285734\t-1.59064191455\t0.203110465493\t-1.2908521807\t0.435694501773\t-2.28469124133\t1.03615153151\t-2.07331471271\t-1.19738904398\t-0.959910526537\t1.77082250572\t-1.82603673248\t-0.183074469692\t-0.51160756486\t-1.01493636671\t-0.751052701677\t-0.295913469367\t0.0786458264067\t-0.191759635661\t-0.192022707223\t0.187123285623\t-1.18407602313\t-1.81837557654\t-0.156625023375\t1.80043424493\t-0.841632867342\t-1.40711836133\t1.24715026778\t-1.96713972783\t1.06507067419\t-0.816203466149\t0.251697805901\t0.857220510587\t-0.764121394231\t-1.55935193095\t1.08311899378\t-1.13915252403\t-1.50402832441\t0.810678070895\t-1.17976988542\t0.373403120599\t0.298981528187\t-1.33330480453\t-0.0687942801303\t-0.377817931557\t-0.614986499574\t4.46006267668\t-0.373017104439\t0.645051800692\t-0.537634324056\t-0.160145731563\t-1.27371519279\t-0.221321870144\t-0.956931511943\t1.36530875164\t-0.458548613035\t-0.645628902274\t-0.689627619734\t0.265309498615\t-0.384760615399\t0.291450789305\t0.738266561153\t0.841000778377\t-0.0602541483071\t-0.637450826603\t0.209274691783\n'
# ipdb> attributes[1000]
# [1.73673022069]
# ipdb> labels_string[1000]
# 'Atal Bihari Vajpayee\t1\t1.73673022069\t-0.924340221314\t-1.26454636702\t-1.7907580728\t-2.08211500121\t-0.784812912723\t-0.822810259754\t-0.265638528704\t-0.838575380537\t-1.87993064508\t-1.79099292071\t-3.20255610583\t-0.0690547163099\t0.0737490000065\t-0.876868845773\t-1.49770844475\t-0.682380496334\t0.184380581993\t-0.0271064814818\t1.40969856676\t0.307730450928\t-1.32360875798\t-0.230528775603\t1.04324119112\t-1.65369995803\t-0.0808220361959\t0.558899594252\t0.789475667551\t0.979902919592\t-1.20434582621\t0.200661302608\t0.410685693758\t-0.505045361753\t-0.642984644448\t0.897926549745\t-0.384973595679\t0.67354621379\t0.543752681147\t0.716510623135\t0.309518663882\t-0.0960284913028\t-0.40942018082\t-0.613167328837\t-0.947713859809\t1.11967383697\t0.256597756276\t-0.341112726452\t0.132659067056\t0.447871247448\t-0.529457221639\t-0.325159626005\t-0.0252541946182\t-0.34471177674\t5.38042994073\t-0.410339919325\t-0.814364803612\t-1.49020393338\t0.562253883632\t0.329644562917\t0.194744860301\t-0.611656790254\t-0.332690757461\t0.0580937143074\t-2.96353836042\t-0.12301331767\t0.933792509176\t-1.62089165618\t-1.21487364821\t0.202652124003\t0.636149827078\t-0.49336313942\t-0.381057099329\t-0.888980324536\n'
# ipdb> corresponding_image_id[1000]
# 1007
# ipdb> image_filenames[1007]
# 'datasets/lfw/lfw-deepfunneled-32/Atal_Bihari_Vajpayee_0001_64x64.jpg'
# ipdb> tbreak 493
# Breakpoint 3 at /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py:493
# ipdb> c
# Creating dataset "datasets/lfw/lfw32_tfrecords"
# Deleted breakpoint 3 at /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py:493
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(493)create_lfw32()
#     492                 tfr.add_image(img)
# --> 493             tfr.add_labels(attributes[order])
#     494
#
# ipdb> image_filenames[corresponding_image_id[order[1000]]]
# 'datasets/lfw/lfw-deepfunneled-32/Jean-David_Levitte_0002_64x64.jpg'
# ipdb> attributes[order]
# array([[ 0.87835653],
#        [ 1.80860775],
#        [ 1.8389861 ],
#        ...,
#        [ 1.01956393],
#        [-0.64521528],
#        [ 0.71994782]])
# ipdb> attributes[order][1000]
# array([ 1.34959775])
# ipdb> corresponding_image_id[order[1000]]
# 5943
# ipdb> attributes[5493]
# array([ 1.31441032])
# ipdb> order[1000]
# 5899
# ipdb> corresponding_image_id[order[1000]]
# 5943
# ipdb> attributes[5899]
# array([ 1.34959775])
# ipdb> image_filenames[corresponding_image_id[order[1000]]]
# 'datasets/lfw/lfw-deepfunneled-32/Jean-David_Levitte_0002_64x64.jpg'
# ipdb> attributes[order][1000]
# array([ 1.34959775])
# ipdb>         attributes = [[float(attribute.strip('\n')) for attribute in label_string.split('\t')[2:]] for label_string in labels_string]
# ipdb>         attributes = np.asarray(attributes)
# ipdb> attributes[order][1000]
# array([ 1.34959775, -1.06123164,  0.36109167, -1.24571116, -1.57068692,
#        -0.69125147, -0.69531654, -0.52060778, -0.20044567, -1.26178545,
#        -0.69314156,  0.40339637, -1.45579916, -0.19330227, -0.78664758,
#        -0.35033635, -0.32377806, -0.77231226,  0.97807099, -1.40899059,
#        -1.34177796,  0.29709735, -0.71250883, -1.13806944,  0.37833655,
#         0.59945071,  0.02204295, -2.15839603,  0.5007411 , -0.37501539,
#        -0.09696073, -0.44213179, -0.00977425, -0.2611627 , -0.02970124,
#        -2.43274384,  0.41805162,  0.98117927,  0.34432044,  0.08460841,
#        -0.64661645,  0.36425793, -1.18078415, -0.35353681,  0.30245967,
#        -0.03183095, -0.5589436 ,  0.20989098, -0.28073982, -0.46557839,
#         0.35248363, -0.30739269, -1.03802008,  0.62304353,  0.01077336,
#        -0.79192712, -0.47944309, -1.5418236 , -0.60847849,  0.33251392,
#        -0.73805565, -4.27043853, -0.80056799, -0.67956581, -0.15024032,
#         0.12048019, -1.02380931, -3.21801281, -0.63900031,  0.03541024,
#        -0.51003849, -0.13272611, -0.56254084])
# ipdb> attributes = [[float(attribute.strip('\n')) for attribute in label_string.split('\t')[2:3]] for label_string in labels_string]
# ipdb> attributes = np.asarray(attributes)
# ipdb> attributes[order][1000]
# array([ 1.34959775])
# ipdb> n
# Added 13143 images.
# --Return--
# None
# > /mnt/disks/disk1/progressive_growing_of_gans/dataset_tool.py(493)create_lfw32()
#     492                 tfr.add_image(img)
# --> 493             tfr.add_labels(attributes[order])
#     494
#
# ipdb> n
# --Call--
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/displayhook.py(247)__call__()
#     246
# --> 247     def __call__(self, result=None):
#     248         """Printing with history cache management.
#
# ipdb> r
# --Return--
# None
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/displayhook.py(254)__call__()
#     253         self.check_for_underscore()
# --> 254         if result is not None and not self.quiet():
#     255             self.start_displayhook()
#
# ipdb> n
# --Return--
# None
# > <ipython-input-2-e24f52261b1e>(5)<module>()
#       3 lfw32_dir = 'datasets/lfw/lfw-deepfunneled-32'
#       4 import ipdb; ipdb.set_trace() # debugging starts here
# ----> 5 dataset_tool.create_lfw32(tfrecord_dir, lfw32_dir, with_attributes=True)
#
# ipdb> n
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2853)run_ast_nodes()
#    2852
# -> 2853             for i, node in enumerate(to_run_interactive):
#    2854                 mod = ast.Interactive([node])
#
# ipdb> r
# --Return--
# False
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2878)run_ast_nodes()
#    2877
# -> 2878         return False
#    2879
#
# ipdb> n
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2730)run_cell()
#    2729
# -> 2730                 self.last_execution_succeeded = not has_raised
#    2731                 self.last_execution_result = result
#
# ipdb> r
# --Return--
# <ExecutionRes...e result=None>
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/IPython/core/interactiveshell.py(2748)run_cell()
#    2747
# -> 2748         return result
#    2749
#
# ipdb> c

# %%
import dataset_tool
tfrecord_dir = 'datasets/cifar10/cifar10_tfrecords'
cifar10_dir = 'datasets/cifar10/cifar-10-batches-py'
import ipdb; ipdb.set_trace() # debugging starts here
dataset_tool.create_cifar10(tfrecord_dir, cifar10_dir)
