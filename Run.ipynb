# %%
# Copyright (c) 2018, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

import os
import time
import numpy as np
import tensorflow as tf

import config
import tfutil
import dataset
import misc

# %%
#----------------------------------------------------------------------------
# Main entry point.
# Calls the function indicated in config.py.
 
if __name__ == "__main__":
    import ipdb; ipdb.set_trace() # debugging starts here
    misc.init_output_logging()
    np.random.seed(config.random_seed)
    print('Initializing TensorFlow...')
    os.environ.update(config.env)
    tfutil.init_tf(config.tf_config)
    print('Running %s()...' % config.train['func'])
    tfutil.call_func_by_name(**config.train)
    print('Exiting...')

#----------------------------------------------------------------------------
# Out:
# > <ipython-input-2-f5faa3ca37b1>(7)<module>()
#       6     import ipdb; ipdb.set_trace() # debugging starts here
# ----> 7     misc.init_output_logging()
#       8     np.random.seed(config.random_seed)
#
# ipdb> c
# Initializing TensorFlow...
# Running train.train_progressive_gan()...
# Streaming data using dataset.TFRecordDataset...
# Dataset shape = [3, 64, 64]
# Dynamic range = [0, 255]
# Label size    = 17
# Loading networks from "results/060-pgan-celeba-cond-preset-v2-1gpu-fp32-GRAPH/network-snapshot-006067.pkl"...
#
# G                           Params      OutputShape             WeightShape
# ---                         ---         ---                     ---
# latents_in                  -           (?, 512)                -
# labels_in                   -           (?, 17)                 -
# fully_connected             1800        (100,)                  -
# fully_connected_1           313856      (512,)                  -
# lod                         -           ()                      -
# 4x4/PixelNorm               -           (?, 512)                -
# 4x4/Dense                   4194816     (512,)                  (512, 8192)
# 4x4/Conv                    2359808     (512,)                  (3, 3, 512, 512)
# ToRGB_lod4                  1539        (3,)                    (1, 1, 512, 3)
# 8x8/Conv0_up                2359808     (512,)                  (3, 3, 512, 512)
# 8x8/Conv1                   2359808     (512,)                  (3, 3, 512, 512)
# ToRGB_lod3                  1539        (3,)                    (1, 1, 512, 3)
# Upscale2D                   -           (?, 3, 8, 8)            -
# Grow_lod3                   -           (?, 3, 8, 8)            -
# 16x16/Conv0_up              2359808     (512,)                  (3, 3, 512, 512)
# 16x16/Conv1                 2359808     (512,)                  (3, 3, 512, 512)
# ToRGB_lod2                  1539        (3,)                    (1, 1, 512, 3)
# Upscale2D_1                 -           (?, 3, 16, 16)          -
# Grow_lod2                   -           (?, 3, 16, 16)          -
# 32x32/Conv0_up              2359808     (512,)                  (3, 3, 512, 512)
# 32x32/Conv1                 2359808     (512,)                  (3, 3, 512, 512)
# ToRGB_lod1                  1539        (3,)                    (1, 1, 512, 3)
# Upscale2D_2                 -           (?, 3, 32, 32)          -
# Grow_lod1                   -           (?, 3, 32, 32)          -
# 64x64/Conv0_up              1179904     (256,)                  (3, 3, 256, 512)
# 64x64/Conv1                 590080      (256,)                  (3, 3, 256, 256)
# ToRGB_lod0                  771         (3,)                    (1, 1, 256, 3)
# Upscale2D_3                 -           (?, 3, 64, 64)          -
# Grow_lod0                   -           (?, 3, 64, 64)          -
# images_out                  -           (?, 3, 64, 64)          -
# ---                         ---         ---                     ---
# Total                       22806039
#
#
# D                           Params      OutputShape             WeightShape
# ---                         ---         ---                     ---
# images_in                   -           (?, 3, 64, 64)          -
# lod                         -           ()                      -
# FromRGB_lod0                1024        (256,)                  (1, 1, 3, 256)
# 64x64/Conv0                 590080      (256,)                  (3, 3, 256, 256)
# 64x64/Conv1_down            1180160     (512,)                  (3, 3, 256, 512)
# Downscale2D                 -           (?, 3, 32, 32)          -
# FromRGB_lod1                2048        (512,)                  (1, 1, 3, 512)
# Grow_lod0                   -           (?, 512, 32, 32)        -
# 32x32/Conv0                 2359808     (512,)                  (3, 3, 512, 512)
# 32x32/Conv1_down            2359808     (512,)                  (3, 3, 512, 512)
# Downscale2D_1               -           (?, 3, 16, 16)          -
# FromRGB_lod2                2048        (512,)                  (1, 1, 3, 512)
# Grow_lod1                   -           (?, 512, 16, 16)        -
# 16x16/Conv0                 2359808     (512,)                  (3, 3, 512, 512)
# 16x16/Conv1_down            2359808     (512,)                  (3, 3, 512, 512)
# Downscale2D_2               -           (?, 3, 8, 8)            -
# FromRGB_lod3                2048        (512,)                  (1, 1, 3, 512)
# Grow_lod2                   -           (?, 512, 8, 8)          -
# 8x8/Conv0                   2359808     (512,)                  (3, 3, 512, 512)
# 8x8/Conv1_down              2359808     (512,)                  (3, 3, 512, 512)
# Downscale2D_3               -           (?, 3, 4, 4)            -
# FromRGB_lod4                2048        (512,)                  (1, 1, 3, 512)
# Grow_lod3                   -           (?, 512, 4, 4)          -
# 4x4/MinibatchStddev         -           (?, 1, 4, 4)            -
# 4x4/Conv                    2364416     (512,)                  (3, 3, 513, 512)
# 4x4/Dense0                  4194816     (512,)                  (8192, 512)
# 4x4/Dense1                  9234        (18,)                   (512, 18)
# scores_out                  -           (?, 1)                  -
# labels_out                  -           (?, 17)                 -
# ---                         ---         ---                     ---
# Total                       22506770
#
# Building TensorFlow graph...
# Setting up snapshot image grid...
# Setting up result dir...
# Saving results to results/063-pgan-celeba-cond-preset-v2-1gpu-fp32-GRAPH
# Training...
# tick 1     kimg 6147.7   lod 0.00  minibatch 32   time 2h 53m 47s   sec/tick 10426.8 sec/kimg 130.33  maintenance 60.4
# tick 2     kimg 6227.7   lod 0.00  minibatch 32   time 5h 47m 40s   sec/tick 10419.9 sec/kimg 130.25  maintenance 12.9
# tick 3     kimg 6307.7   lod 0.00  minibatch 32   time 8h 42m 23s   sec/tick 10478.4 sec/kimg 130.98  maintenance 4.8
# tick 4     kimg 6387.7   lod 0.00  minibatch 32   time 11h 36m 37s  sec/tick 10449.6 sec/kimg 130.62  maintenance 5.0
# tick 5     kimg 6467.7   lod 0.00  minibatch 32   time 14h 30m 48s  sec/tick 10445.8 sec/kimg 130.57  maintenance 4.8
#
# Program interrupted. (Use 'cont' to resume).
# --Call--
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py(510)__exit__()
#     509
# --> 510   def __exit__(self, type_arg, value_arg, traceback_arg):
#     511     try:
#
# ipdb> c
