# %%
# Copyright (c) 2018, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

import os
import time
import numpy as np
import tensorflow as tf

import config
import tfutil
import dataset
import misc

# %%
#----------------------------------------------------------------------------
# Main entry point.
# Calls the function indicated in config.py.

if __name__ == "__main__":
    import ipdb; ipdb.set_trace() # debugging starts here
    misc.init_output_logging()
    np.random.seed(config.random_seed)
    print('Initializing TensorFlow...')
    os.environ.update(config.env)
    tfutil.init_tf(config.tf_config)
    print('Running %s()...' % config.train['func'])
    tfutil.call_func_by_name(**config.train)
    print('Exiting...')

#----------------------------------------------------------------------------
# Out:
# > <ipython-input-2-55677d9f7407>(7)<module>()
#       6     import ipdb; ipdb.set_trace() # debugging starts here
# ----> 7     misc.init_output_logging()
#       8     np.random.seed(config.random_seed)
#
# ipdb> tbreak train.py:151
# Breakpoint 1 at /mnt/disks/disk1/progressive_growing_of_gans/train.py:151
# ipdb> c
# Initializing TensorFlow...
# Running train.train_progressive_gan()...
# Deleted breakpoint 1 at /mnt/disks/disk1/progressive_growing_of_gans/train.py:151
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(151)train_progressive_gan()
#     150     maintenance_start_time = time.time()
# --> 151     training_set = dataset.load_dataset(data_dir=config.data_dir, verbose=True, **config.dataset)
#     152
#
# ipdb> n
# Streaming data using dataset.TFRecordDataset...
# Dataset shape = [3, 32, 32]
# Dynamic range = [0, 255]
# Label size    = 1
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(154)train_progressive_gan()
#     153     # Construct networks.
# --> 154     with tf.device('/gpu:0'):
#     155         if resume_run_id is not None:
#
# ipdb> training_set
# <dataset.TFRecordDataset object at 0x7f5ef3495f98>
# ipdb> training_set.get_random_labels_np(3)
# array([[-1.66033137],
#        [-1.50393462],
#        [ 1.11111176]], dtype=float32)
# ipdb> training_set.label_size
# 1
# ipdb> training_set.get_minibatch_np(1)
# (array([[[[105,  97, 111, ...,  43,  31,  34],
#          [ 99, 103, 116, ...,  44,  41,  44],
#          [101, 109, 117, ...,  43,  51,  48],
#          ...,
#          [ 97, 104,  96, ...,  72, 114, 119],
#          [109, 124, 127, ...,  88, 107, 114],
#          [120, 137, 147, ...,  94,  88,  99]],
#
#         [[107,  96, 109, ...,  42,  27,  29],
#          [101, 102, 115, ...,  40,  36,  37],
#          [100, 109, 116, ...,  35,  42,  38],
#          ...,
#          [103, 110, 101, ...,  47,  93,  99],
#          [118, 130, 132, ...,  65,  91,  99],
#          [129, 146, 153, ...,  74,  72,  86]],
#
#         [[122, 110, 120, ...,  47,  26,  25],
#          [116, 116, 123, ...,  41,  32,  29],
#          [114, 121, 124, ...,  32,  33,  26],
#          ...,
#          [101, 106,  95, ...,  16,  64,  74],
#          [115, 128, 128, ...,  31,  58,  70],
#          [126, 143, 149, ...,  37,  39,  54]]]], dtype=uint8), array([[-1.77849996]], dtype=float32))
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(155)train_progressive_gan()
#     154     with tf.device('/gpu:0'):
# --> 155         if resume_run_id is not None:
#     156             network_pkl = misc.locate_network_pkl(resume_run_id, resume_snapshot)
#
# ipdb> c
# Constructing networks...
#
# G                           Params      OutputShape             WeightShape
# ---                         ---         ---                     ---
# latents_in                  -           (?, 512)                -
# labels_in                   -           (?, 1)                  -
# lod                         -           ()                      -
# 4x4/PixelNorm               -           (?, 513)                -
# 4x4/Dense                   4203008     (?, 512, 4, 4)          (513, 8192)
# 4x4/Conv                    2359808     (?, 512, 4, 4)          (3, 3, 512, 512)
# ToRGB_lod3                  1539        (?, 3, 4, 4)            (1, 1, 512, 3)
# 8x8/Conv0_up                2359808     (?, 512, 8, 8)          (3, 3, 512, 512)
# 8x8/Conv1                   2359808     (?, 512, 8, 8)          (3, 3, 512, 512)
# ToRGB_lod2                  1539        (?, 3, 8, 8)            (1, 1, 512, 3)
# Upscale2D                   -           (?, 3, 8, 8)            -
# Grow_lod2                   -           (?, 3, 8, 8)            -
# 16x16/Conv0_up              2359808     (?, 512, 16, 16)        (3, 3, 512, 512)
# 16x16/Conv1                 2359808     (?, 512, 16, 16)        (3, 3, 512, 512)
# ToRGB_lod1                  1539        (?, 3, 16, 16)          (1, 1, 512, 3)
# Upscale2D_1                 -           (?, 3, 16, 16)          -
# Grow_lod1                   -           (?, 3, 16, 16)          -
# 32x32/Conv0_up              2359808     (?, 512, 32, 32)        (3, 3, 512, 512)
# 32x32/Conv1                 2359808     (?, 512, 32, 32)        (3, 3, 512, 512)
# ToRGB_lod0                  1539        (?, 3, 32, 32)          (1, 1, 512, 3)
# Upscale2D_2                 -           (?, 3, 32, 32)          -
# Grow_lod0                   -           (?, 3, 32, 32)          -
# images_out                  -           (?, 3, 32, 32)          -
# ---                         ---         ---                     ---
# Total                       20727820
#
#
# D                           Params      OutputShape             WeightShape
# ---                         ---         ---                     ---
# images_in                   -           (?, 3, 32, 32)          -
# lod                         -           ()                      -
# FromRGB_lod0                2048        (?, 512, 32, 32)        (1, 1, 3, 512)
# 32x32/Conv0                 2359808     (?, 512, 32, 32)        (3, 3, 512, 512)
# 32x32/Conv1_down            2359808     (?, 512, 16, 16)        (3, 3, 512, 512)
# Downscale2D                 -           (?, 3, 16, 16)          -
# FromRGB_lod1                2048        (?, 512, 16, 16)        (1, 1, 3, 512)
# Grow_lod0                   -           (?, 512, 16, 16)        -
# 16x16/Conv0                 2359808     (?, 512, 16, 16)        (3, 3, 512, 512)
# 16x16/Conv1_down            2359808     (?, 512, 8, 8)          (3, 3, 512, 512)
# Downscale2D_1               -           (?, 3, 8, 8)            -
# FromRGB_lod2                2048        (?, 512, 8, 8)          (1, 1, 3, 512)
# Grow_lod1                   -           (?, 512, 8, 8)          -
# 8x8/Conv0                   2359808     (?, 512, 8, 8)          (3, 3, 512, 512)
# 8x8/Conv1_down              2359808     (?, 512, 4, 4)          (3, 3, 512, 512)
# Downscale2D_2               -           (?, 3, 4, 4)            -
# FromRGB_lod3                2048        (?, 512, 4, 4)          (1, 1, 3, 512)
# Grow_lod2                   -           (?, 512, 4, 4)          -
# 4x4/MinibatchStddev         -           (?, 1, 4, 4)            -
# 4x4/Conv                    2364416     (?, 512, 4, 4)          (3, 3, 513, 512)
# 4x4/Dense0                  4194816     (?, 512)                (8192, 512)
# 4x4/Dense1                  1026        (?, 2)                  (512, 2)
# scores_out                  -           (?, 1)                  -
# labels_out                  -           (?, 1)                  -
# ---                         ---         ---                     ---
# Total                       20727298
#
# Building TensorFlow graph...
# Setting up snapshot image grid...
# Setting up result dir...
# Saving results to results/007-pgan-lfw32-cond-preset-v2-1gpu-fp32-GRAPH
# Training...
# tick 1     kimg 160.3    lod 3.00  minibatch 128  time 3m 08s       sec/tick 187.9   sec/kimg 1.17    maintenance 658.4
# tick 2     kimg 320.5    lod 3.00  minibatch 128  time 6m 18s       sec/tick 184.0   sec/kimg 1.15    maintenance 6.1
# tick 3     kimg 480.8    lod 3.00  minibatch 128  time 9m 22s       sec/tick 184.2   sec/kimg 1.15    maintenance 0.2
# tick 4     kimg 621.1    lod 2.97  minibatch 128  time 14m 00s      sec/tick 277.8   sec/kimg 1.98    maintenance 0.2
#
# Program interrupted. (Use 'cont' to resume).
# --Call--
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py(510)__exit__()
#     509
# --> 510   def __exit__(self, type_arg, value_arg, traceback_arg):
#     511     try:
#
# ipdb> tbreak train.py:222
# Breakpoint 2 at /mnt/disks/disk1/progressive_growing_of_gans/train.py:222
# ipdb> c
# Deleted breakpoint 2 at /mnt/disks/disk1/progressive_growing_of_gans/train.py:222
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(222)train_progressive_gan()
#     221         # Choose training parameters and configure training ops.
# --> 222         sched = TrainingSchedule(cur_nimg, training_set, **config.sched)
#     223         training_set.configure(sched.minibatch, sched.lod)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(223)train_progressive_gan()
#     222         sched = TrainingSchedule(cur_nimg, training_set, **config.sched)
# --> 223         training_set.configure(sched.minibatch, sched.lod)
#     224         if reset_opt_for_new_lod:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(224)train_progressive_gan()
#     223         training_set.configure(sched.minibatch, sched.lod)
# --> 224         if reset_opt_for_new_lod:
#     225             if np.floor(sched.lod) != np.floor(prev_lod) or np.ceil(sched.lod) != np.ceil(prev_lod):
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(225)train_progressive_gan()
#     224         if reset_opt_for_new_lod:
# --> 225             if np.floor(sched.lod) != np.floor(prev_lod) or np.ceil(sched.lod) != np.ceil(prev_lod):
#     226                 G_opt.reset_optimizer_state(); D_opt.reset_optimizer_state()
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(227)train_progressive_gan()
#     226                 G_opt.reset_optimizer_state(); D_opt.reset_optimizer_state()
# --> 227         prev_lod = sched.lod
#     228
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(230)train_progressive_gan()
#     229         # Run training ops.
# --> 230         for repeat in range(minibatch_repeats):
#     231             for _ in range(D_repeats):
#
# ipdb> minibatch_repeats
# 4
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(231)train_progressive_gan()
#     230         for repeat in range(minibatch_repeats):
# --> 231             for _ in range(D_repeats):
#     232                 tfutil.run([D_train_op, Gs_update_op], {lod_in: sched.lod, lrate_in: sched.D_lrate, minibatch_in: sched.minibatch})
#
# ipdb> tbreak 222
# Breakpoint 3 at /mnt/disks/disk1/progressive_growing_of_gans/train.py:222
