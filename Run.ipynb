# %%
# Copyright (c) 2018, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

import os
import time
import numpy as np
import tensorflow as tf

import config
import tfutil
import dataset
import misc

# %%
#----------------------------------------------------------------------------
# Main entry point.
# Calls the function indicated in config.py.

if __name__ == "__main__":
    import ipdb; ipdb.set_trace() # debugging starts here
    misc.init_output_logging()
    np.random.seed(config.random_seed)
    print('Initializing TensorFlow...')
    os.environ.update(config.env)
    tfutil.init_tf(config.tf_config)
    print('Running %s()...' % config.train['func'])
    tfutil.call_func_by_name(**config.train)
    print('Exiting...')

#----------------------------------------------------------------------------
# Out:
# > <ipython-input-8-55677d9f7407>(7)<module>()
#       6     import ipdb; ipdb.set_trace() # debugging starts here
# ----> 7     misc.init_output_logging()
#       8     np.random.seed(config.random_seed)
#
# ipdb> n
# > <ipython-input-8-55677d9f7407>(8)<module>()
#       7     misc.init_output_logging()
# ----> 8     np.random.seed(config.random_seed)
#       9     print('Initializing TensorFlow...')
#
# ipdb> n
# > <ipython-input-8-55677d9f7407>(9)<module>()
#       8     np.random.seed(config.random_seed)
# ----> 9     print('Initializing TensorFlow...')
#      10     os.environ.update(config.env)
#
# ipdb> n
# Initializing TensorFlow...
# > <ipython-input-8-55677d9f7407>(10)<module>()
#       9     print('Initializing TensorFlow...')
# ---> 10     os.environ.update(config.env)
#      11     tfutil.init_tf(config.tf_config)
#
# ipdb> n
# > <ipython-input-8-55677d9f7407>(11)<module>()
#      10     os.environ.update(config.env)
# ---> 11     tfutil.init_tf(config.tf_config)
#      12     print('Running %s()...' % config.train['func'])
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(55)init_tf()
#      54
# ---> 55 def init_tf(config_dict=dict()):
#      56     if tf.get_default_session() is None:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(56)init_tf()
#      55 def init_tf(config_dict=dict()):
# ---> 56     if tf.get_default_session() is None:
#      57         tf.set_random_seed(np.random.randint(1 << 31))
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(57)init_tf()
#      56     if tf.get_default_session() is None:
# ---> 57         tf.set_random_seed(np.random.randint(1 << 31))
#      58         create_session(config_dict, force_as_default=True)
#
# ipdb> s
# --Call--
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/random_seed.py(83)set_random_seed()
#      82
# ---> 83 @tf_export('set_random_seed')
#      84 def set_random_seed(seed):
#
# ipdb> n
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/random_seed.py(179)set_random_seed()
#     178   """
# --> 179   if context.in_graph_mode():
#     180     ops.get_default_graph().seed = seed
#
# ipdb> n
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/random_seed.py(180)set_random_seed()
#     179   if context.in_graph_mode():
# --> 180     ops.get_default_graph().seed = seed
#     181   else:
#
# ipdb> n
# --Return--
# None
# > /home/moham/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/random_seed.py(180)set_random_seed()
#     179   if context.in_graph_mode():
# --> 180     ops.get_default_graph().seed = seed
#     181   else:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(58)init_tf()
#      57         tf.set_random_seed(np.random.randint(1 << 31))
# ---> 58         create_session(config_dict, force_as_default=True)
#      59
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(64)create_session()
#      63
# ---> 64 def create_session(config_dict=dict(), force_as_default=False):
#      65     config = tf.ConfigProto()
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(65)create_session()
#      64 def create_session(config_dict=dict(), force_as_default=False):
# ---> 65     config = tf.ConfigProto()
#      66     for key, value in config_dict.items():
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(66)create_session()
#      65     config = tf.ConfigProto()
# ---> 66     for key, value in config_dict.items():
#      67         fields = key.split('.')
#
# ipdb> config_dict.items()
# dict_items([('graph_options.place_pruned_graph', True)])
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(67)create_session()
#      66     for key, value in config_dict.items():
# ---> 67         fields = key.split('.')
#      68         obj = config
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(68)create_session()
#      67         fields = key.split('.')
# ---> 68         obj = config
#      69         for field in fields[:-1]:
#
# ipdb> fields
# ['graph_options', 'place_pruned_graph']
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(69)create_session()
#      68         obj = config
# ---> 69         for field in fields[:-1]:
#      70             obj = getattr(obj, field)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(70)create_session()
#      69         for field in fields[:-1]:
# ---> 70             obj = getattr(obj, field)
#      71         setattr(obj, fields[-1], value)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(69)create_session()
#      68         obj = config
# ---> 69         for field in fields[:-1]:
#      70             obj = getattr(obj, field)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(71)create_session()
#      70             obj = getattr(obj, field)
# ---> 71         setattr(obj, fields[-1], value)
#      72     session = tf.Session(config=config)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(66)create_session()
#      65     config = tf.ConfigProto()
# ---> 66     for key, value in config_dict.items():
#      67         fields = key.split('.')
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(72)create_session()
#      71         setattr(obj, fields[-1], value)
# ---> 72     session = tf.Session(config=config)
#      73     if force_as_default:
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(73)create_session()
#      72     session = tf.Session(config=config)
# ---> 73     if force_as_default:
#      74         session._default_session = session.as_default()
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(74)create_session()
#      73     if force_as_default:
# ---> 74         session._default_session = session.as_default()
#      75         session._default_session.enforce_nesting = False
#
# ipdb> force_as_default
# True
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(75)create_session()
#      74         session._default_session = session.as_default()
# ---> 75         session._default_session.enforce_nesting = False
#      76         session._default_session.__enter__()
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(76)create_session()
#      75         session._default_session.enforce_nesting = False
# ---> 76         session._default_session.__enter__()
#      77     return session
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(77)create_session()
#      76         session._default_session.__enter__()
# ---> 77     return session
#      78
#
# ipdb> n
# --Return--
# <tensorflow.p...x7f96b8fc8080>
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(77)create_session()
#      76         session._default_session.__enter__()
# ---> 77     return session
#      78
# ipdb> n
# --Return--
# None
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(58)init_tf()
#      57         tf.set_random_seed(np.random.randint(1 << 31))
# ---> 58         create_session(config_dict, force_as_default=True)
#      59
#
# ipdb> n
# > <ipython-input-8-55677d9f7407>(12)<module>()
#      11     tfutil.init_tf(config.tf_config)
# ---> 12     print('Running %s()...' % config.train['func'])
#      13     tfutil.call_func_by_name(**config.train)
#
# ipdb> n
# Running train.train_progressive_gan()...
# > <ipython-input-8-55677d9f7407>(13)<module>()
#      12     print('Running %s()...' % config.train['func'])
# ---> 13     tfutil.call_func_by_name(**config.train)
#      14     print('Exiting...')
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(234)call_func_by_name()
#     233
# --> 234 def call_func_by_name(*args, func=None, **kwargs):
#     235     assert func is not None
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(235)call_func_by_name()
#     234 def call_func_by_name(*args, func=None, **kwargs):
# --> 235     assert func is not None
#     236     return import_obj(func)(*args, **kwargs)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(236)call_func_by_name()
#     235     assert func is not None
# --> 236     return import_obj(func)(*args, **kwargs)
#     237
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(230)import_obj()
#     229
# --> 230 def import_obj(obj_name):
#     231     module, relative_obj_name = import_module(obj_name)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(231)import_obj()
#     230 def import_obj(obj_name):
# --> 231     module, relative_obj_name = import_module(obj_name)
#     232     return find_obj_in_module(module, relative_obj_name)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(232)import_obj()
#     231     module, relative_obj_name = import_module(obj_name)
# --> 232     return find_obj_in_module(module, relative_obj_name)
#     233
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(224)find_obj_in_module()
#     223
# --> 224 def find_obj_in_module(module, relative_obj_name):
#     225     obj = module
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(225)find_obj_in_module()
#     224 def find_obj_in_module(module, relative_obj_name):
# --> 225     obj = module
#     226     for part in relative_obj_name.split('.'):
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(226)find_obj_in_module()
#     225     obj = module
# --> 226     for part in relative_obj_name.split('.'):
#     227         obj = getattr(obj, part)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(227)find_obj_in_module()
#     226     for part in relative_obj_name.split('.'):
# --> 227         obj = getattr(obj, part)
#     228     return obj
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(226)find_obj_in_module()
#     225     obj = module
# --> 226     for part in relative_obj_name.split('.'):
#     227         obj = getattr(obj, part)
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(228)find_obj_in_module()
#     227         obj = getattr(obj, part)
# --> 228     return obj
#     229
#
# ipdb> relative_obj_name.split('.')
# ['train_progressive_gan']
# ipdb> obj
# <function train_progressive_gan at 0x7f96b8fd3ea0>
# ipdb> s
# --Return--
# <function tra...x7f96b8fd3ea0>
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(228)find_obj_in_module()
#     227         obj = getattr(obj, part)
# --> 228     return obj
#     229
# ipdb> s
# --Return--
# <function tra...x7f96b8fd3ea0>
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(232)import_obj()
#     231     module, relative_obj_name = import_module(obj_name)
# --> 232     return find_obj_in_module(module, relative_obj_name)
#     233
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/train.py(133)train_progressive_gan()
#     132
# --> 133 def train_progressive_gan(
#     134     G_smoothing             = 0.999,        # Exponential running average of generator weights.
