# %%
# Copyright (c) 2018, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

import os
import time
import numpy as np
import tensorflow as tf

import config
import tfutil
import dataset
import misc

# %%
#----------------------------------------------------------------------------
# Main entry point.
# Calls the function indicated in config.py.

if __name__ == "__main__":
    import ipdb; ipdb.set_trace() # debugging starts here
    misc.init_output_logging()
    np.random.seed(config.random_seed)
    print('Initializing TensorFlow...')
    os.environ.update(config.env)
    tfutil.init_tf(config.tf_config)
    print('Running %s()...' % config.train['func'])
    tfutil.call_func_by_name(**config.train)
    print('Exiting...')

#----------------------------------------------------------------------------
# Out:
# > <ipython-input-2-55677d9f7407>(7)<module>()
#       6     import ipdb; ipdb.set_trace() # debugging starts here
# ----> 7     misc.init_output_logging()
#       8     np.random.seed(config.random_seed)
#
# ipdb> b tfutil.py:432
# Breakpoint 1 at /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py:432
# ipdb> b tfutil.py:433
# Breakpoint 2 at /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py:433
# ipdb> c
# Initializing TensorFlow...
# Running train.train_progressive_gan()...
# Streaming data using dataset.TFRecordDataset...
# Dataset shape = [3, 32, 32]
# Dynamic range = [0, 255]
# Label size    = 0
# Constructing networks...
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(432)__init__()
#     431         # Init graph.
# 1-> 432         self._init_graph()
# 2   433         self.reset_vars()
#
# ipdb> s
# --Call--
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(456)_init_graph()
#     455
# --> 456     def _init_graph(self):
#     457         # Collect inputs.
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(458)_init_graph()
#     457         # Collect inputs.
# --> 458         self.input_names = []
#     459         for param in inspect.signature(self._build_func).parameters.values():
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(459)_init_graph()
#     458         self.input_names = []
# --> 459         for param in inspect.signature(self._build_func).parameters.values():
#     460             if param.kind == param.POSITIONAL_OR_KEYWORD and param.default is param.empty:
#
# ipdb> inspect.signature(self._build_func).parameters.values()
# odict_values([<Parameter "latents_in">, <Parameter "labels_in">, <Parameter "num_channels=1">, <Parameter "resolution=32">, <Parameter "label_size=0">, <Parameter "fmap_base=8192">, <Parameter "fmap_decay=1.0">, <Parameter "fmap_max=512">, <Parameter "latent_size=None">, <Parameter "normalize_latents=True">, <Parameter "use_wscale=True">, <Parameter "use_pixelnorm=True">, <Parameter "pixelnorm_epsilon=1e-08">, <Parameter "use_leakyrelu=True">, <Parameter "dtype='float32'">, <Parameter "fused_scale=True">, <Parameter "structure=None">, <Parameter "is_template_graph=False">, <Parameter "**kwargs">])
# ipdb> signature(self._build_func)
# *** NameError: name 'signature' is not defined
# ipdb> inspect.signature(self._build_func)
# <Signature (latents_in, labels_in, num_channels=1, resolution=32, label_size=0, fmap_base=8192, fmap_decay=1.0, fmap_max=512, latent_size=None, normalize_latents=True, use_wscale=True, use_pixelnorm=True, pixelnorm_epsilon=1e-08, use_leakyrelu=True, dtype='float32', fused_scale=True, structure=None, is_template_graph=False, **kwargs)>
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(460)_init_graph()
#     459         for param in inspect.signature(self._build_func).parameters.values():
# --> 460             if param.kind == param.POSITIONAL_OR_KEYWORD and param.default is param.empty:
#     461                 self.input_names.append(param.name)
#
# ipdb> param.POSITIONAL_OR_KEYWORD
# <_ParameterKind.POSITIONAL_OR_KEYWORD: 1>
# ipdb> param.kind
# <_ParameterKind.POSITIONAL_OR_KEYWORD: 1>
# ipdb> param.default
# <class 'inspect._empty'>
# ipdb> self.input_names
# []
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(461)_init_graph()
#     460             if param.kind == param.POSITIONAL_OR_KEYWORD and param.default is param.empty:
# --> 461                 self.input_names.append(param.name)
#     462         self.num_inputs = len(self.input_names)
#
# ipdb> unt
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(462)_init_graph()
#     461                 self.input_names.append(param.name)
# --> 462         self.num_inputs = len(self.input_names)
#     463         assert self.num_inputs >= 1
#
# ipdb> self.input_names
# ['latents_in', 'labels_in']
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(463)_init_graph()
#     462         self.num_inputs = len(self.input_names)
# --> 463         assert self.num_inputs >= 1
#     464
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(466)_init_graph()
#     465         # Choose name and scope.
# --> 466         if self.name is None:
#     467             self.name = self._build_func_name
#
# ipdb> self
# <tfutil.Network object at 0x7f6a6bc40eb8>
# ipdb> self.name
# 'G'
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(468)_init_graph()
#     467             self.name = self._build_func_name
# --> 468         self.scope = tf.get_default_graph().unique_name(self.name.replace('/', '_'), mark_as_used=False)
#     469
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(471)_init_graph()
#     470         # Build template graph.
# --> 471         with tf.variable_scope(self.scope, reuse=tf.AUTO_REUSE):
#     472             assert tf.get_variable_scope().name == self.scope
#
# ipdb> self.scope
# 'G'
# ipdb> tf.get_default_graph()
# <tensorflow.python.framework.ops.Graph object at 0x7f6a6bc402e8>
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(472)_init_graph()
#     471         with tf.variable_scope(self.scope, reuse=tf.AUTO_REUSE):
# --> 472             assert tf.get_variable_scope().name == self.scope
#     473             with absolute_name_scope(self.scope): # ignore surrounding name_scope
#
# ipdb> tf.get_variable_scope().name
# 'G'
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(473)_init_graph()
#     472             assert tf.get_variable_scope().name == self.scope
# --> 473             with absolute_name_scope(self.scope): # ignore surrounding name_scope
#     474                 with tf.control_dependencies(None): # ignore surrounding control_dependencies
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(474)_init_graph()
#     473             with absolute_name_scope(self.scope): # ignore surrounding name_scope
# --> 474                 with tf.control_dependencies(None): # ignore surrounding control_dependencies
#     475                     self.input_templates = [tf.placeholder(tf.float32, name=name) for name in self.input_names]
#
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(475)_init_graph()
#     474                 with tf.control_dependencies(None): # ignore surrounding control_dependencies
# --> 475                     self.input_templates = [tf.placeholder(tf.float32, name=name) for name in self.input_names]
#     476                     out_expr = self._build_func(*self.input_templates, is_template_graph=True, **self.static_kwargs)
#
# ipdb> self.input_names
# ['latents_in', 'labels_in']
# ipdb> n
# > /mnt/disks/disk1/progressive_growing_of_gans/tfutil.py(476)_init_graph()
#     475                     self.input_templates = [tf.placeholder(tf.float32, name=name) for name in self.input_names]
# --> 476                     out_expr = self._build_func(*self.input_templates, is_template_graph=True, **self.static_kwargs)
#     477
#
# ipdb> self.input_templates
# [<tf.Tensor 'G/latents_in:0' shape=<unknown> dtype=float32>, <tf.Tensor 'G/labels_in:0' shape=<unknown> dtype=float32>]
